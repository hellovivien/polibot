# %%
import sys
sys.path.insert(0, "..")
import snscrape.modules.twitter as sntwitter
from fastapi.encoders import jsonable_encoder
import json
import pandas as pd
import numpy as np
from pymongo import MongoClient
import datetime
import re
from config import conf

df = pd.read_excel('../datasets/deputes.xlsx', sheet_name="deputes-active")
df_party = pd.read_excel('../datasets/deputes.xlsx', sheet_name="parties-politiques")

# %%
df_party
# Out:
#      group          twitter
# 0   AGIR-E  AgirEnsemble_AN
# 1      DEM            MoDem
# 2      DLF     DLF_Officiel
# 3      EDS        edsassnat
# 4       FI  FranceInsoumise
# 5      GDR       deputesPCF
# 6       GE        GEcologie
# 7    LAREM       enmarchefr
# 8      LDS       Liguedusud
# 9      LND     NDemocrates_
# 10      LR  lesRepublicains
# 11      LT  GroupeLibTerrAN
# 12      RN    RNational_off
# 13     SOC    socialistesAN
# 14   UDI_I          UDI_off

# %%
df1 = df.copy()

def get_sex(civil):
    if civil.upper() == 'M.':
        return 'm'
    else:
        return 'f'

def fix_account_name(input):
    if type(input) == str:
        return input.replace('@', '')
    else:
        return input
  

df1['sex'] = df1.civ.apply(get_sex)
df1['twitter'] = df1.twitter.apply(fix_account_name)
df1
# Out:
#            id  legislature  civ             nom      prenom  naissance   age  \
# 0    PA267355         15.0   M.           Herth     Antoine 1963-02-14  58.0
# 1    PA267780         15.0  Mme  Firmin Le Bodo       Agnès 1968-11-20  52.0
# 2    PA642868         15.0   M.      Christophe        Paul 1971-02-10  50.0
# 3    PA642935         15.0   M.           Becht     Olivier 1976-04-28  45.0
# 4    PA702052         15.0  Mme            Sage       Maina 1975-05-10  46.0
# ..        ...          ...  ...             ...         ...        ...   ...
# 568  PA721094         15.0   M.         Dunoyer    Philippe 1968-01-11  53.0
# 569  PA721110         15.0  Mme         Sanquer      Nicole 1972-06-16  49.0
# 570  PA721486         15.0   M.        Naegelen  Christophe 1983-12-30  37.0
# 571  PA783463         15.0  Mme        Métadier      Sophie 1961-04-26  60.0
# 572  PA721174         15.0   M.      Son-Forget     Joachim 1983-04-15  38.0
#
#                   groupe         groupeSansNI groupeAbrev  ...  \
# 0          Agir ensemble        Agir ensemble      AGIR-E  ...
# 1          Agir ensemble        Agir ensemble      AGIR-E  ...
# 2          Agir ensemble        Agir ensemble      AGIR-E  ...
# 3          Agir ensemble        Agir ensemble      AGIR-E  ...
# 4          Agir ensemble        Agir ensemble      AGIR-E  ...
# ..                   ...                  ...         ...  ...
# 568  UDI et Indépendants  UDI et Indépendants       UDI_I  ...
# 569  UDI et Indépendants  UDI et Indépendants       UDI_I  ...
# 570  UDI et Indépendants  UDI et Indépendants       UDI_I  ...
# 571  UDI et Indépendants  UDI et Indépendants       UDI_I  ...
# 572          Non inscrit       Valeur Absolue          NI  ...
#
#                                             facebook                 website  \
# 0                                      antoine.herth   www.antoine-herth.fr/
# 1                                  agnesfirminlebodo                     NaN
# 2    Paul-Christophe-Député-du-Nord-1387587231318843     paulchristophe.fr/
# 3                                     OlivierBecht68  www.becht-groff2017.fr
# 4                                   MainaSageDeputee        www.mainasage.fr
# ..                                               ...                     ...
# 568                              philippedunoyer2017                     NaN
# 569                             nicolesanquerfareata                     NaN
# 570                         ChristopheNaegelenVosges         www.naegelen.fr
# 571                                              NaN                     NaN
# 572                                   joachim.forget     joachimsonforget.fr
#
#     nombreMandats  experienceDepute scoreParticipation  \
# 0             4.0            19 ans               0.14
# 1             1.0             4 ans               0.25
# 2             1.0             4 ans               0.27
# 3             1.0             4 ans               0.12
# 4             2.0             7 ans               0.14
# ..            ...               ...                ...
# 568           1.0             4 ans               0.08
# 569           1.0             4 ans               0.08
# 570           1.0             4 ans               0.13
# 571           1.0            5 mois               0.05
# 572           1.0             4 ans               0.06
#
#     scoreParticipationSpecialite scoreLoyaute scoreMajorite    dateMaj sex
# 0                           0.21        0.937         0.767 2021-08-22   m
# 1                           0.53        0.918         0.723 2021-08-22   f
# 2                           0.71        0.944         0.649 2021-08-22   m
# 3                           0.68        0.966         0.703 2021-08-22   m
# 4                           0.26        0.977         0.545 2021-08-22   f
# ..                           ...          ...           ...        ...  ..
# 568                         0.17        0.741         0.500 2021-08-22   m
# 569                         0.14        0.769         0.545 2021-08-22   f
# 570                         0.14        0.925         0.386 2021-08-22   m
# 571                          NaN          NaN         0.571 2021-08-22   f
# 572                         0.33        0.641         0.683 2021-08-22   m
#
# [573 rows x 28 columns]

# %%
df1.rename(columns={"nom": "last_name", "prenom": "first_name", "groupeAbrevSansNI":"group", "groupeSansNI":"group_name", "departementCode":"postal_code", "naissance":'birthday', "mail":"email", "experienceDepute":"deputy_years", "datePriseFonction":"deputy_since", "id":"source_id"}, inplace=True)

# %%
df1.sample(1).T
# Out:
#                                                                             489
# source_id                                                              PA722390
# legislature                                                                15.0
# civ                                                                         Mme
# last_name                                                             Corneloup
# first_name                                                              Josiane
# birthday                                                    1959-09-30 00:00:00
# age                                                                        61.0
# groupe                                                         Les Républicains
# group_name                                                     Les Républicains
# groupeAbrev                                                                  LR
# group                                                                        LR
# departementNom                                                   Saône-et-Loire
# postal_code                                                                71.0
# circo                                                                       2.0
# deputy_since                                                2017-06-21 00:00:00
# job                                                                Pharmacienne
# email                                  josiane.corneloup@assemblee-nationale.fr
# twitter                                                                     NaN
# facebook                      Josiane-Corneloup-députée-de-Saône-et-Loire-13...
# website                                                     josianecorneloup.fr
# nombreMandats                                                               1.0
# deputy_years                                                              4 ans
# scoreParticipation                                                         0.15
# scoreParticipationSpecialite                                               0.28
# scoreLoyaute                                                              0.915
# scoreMajorite                                                             0.237
# dateMaj                                                     2021-08-22 00:00:00
# sex                                                                           f

# %%
df1.shape
# Out:
# (573, 28)

# %%
df1.twitter.isna().sum()
# Out:
# 62

# %%
df1.dropna(subset=['twitter'],inplace=True)
df1.shape
# Out:
# (511, 28)

# %%
df1.twitter.value_counts()
# Out:
# antoineherth       1
# damienadam76       1
# flprovendier       1
# JMaireofficiel     1
# BeaudouinSo        1
#                   ..
# jacqlinedubois     1
# dmartindijon       1
# MonicaMichel_Of    1
# FCBDeputeduCher    1
# sonjoachim         1
# Name: twitter, Length: 511, dtype: int64

# %%
client = MongoClient(conf['mongo_uri'])
db = client.politweet

def get_account(account_dict):
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:{}'.format(account_dict['twitter'])).get_items()):
        account = json.loads(tweet.user.json())
        field_to_del = ['_type', 'linkTcourl']
        field_to_add = ['source_id','last_name','first_name','birthday','group_name','group','postal_code','deputy_since','deputy_years','job','email','facebook','website','sex']
        for field in field_to_del: 
            account.pop(field, None)
        for field in field_to_add:
            account[field] = account_dict[field]
        return account
    

def get_oldest_date_tweet(to_str=False):
    res = list(db.tweets.find({},{'date':1}).sort('date', 1).limit(1))
    date = res[0]['date']
    if to_str:
        date = date.strftime('%A %d/%m/%Y à %H:%M') # lundi 04/05/2020 à 12h51
    return date    

def build_tweet(tweet, account, party=False):
    if party:
        tweet_dict = {
            'group':account['group'],
            'account_username':account['username']
        }
    else:        
        tweet_dict = {
            'group':account['group'],
            'account_username':account['username'],
            'account_first_name':account['first_name'],
            'account_last_name':account['last_name'],
            'account_id':account['_id'],
            # 'content_en':translate(tweet.content)
        }
    fields_to_keep = ['url','date','content','renderedContent','id','replyCount','retweetCount','likeCount','quoteCount','conversationId','lang','sourceLabel','hashtags','cashtags']
    fields_to_bool = ['retweetedTweet','quotedTweet','inReplyToTweetId','mentionedUsers']
    for field in fields_to_keep:
        if hasattr(tweet, field):
            tweet_dict[field] = getattr(tweet, field)
    for field in fields_to_bool:
        if hasattr(tweet, field):
            tweet_dict[field] = bool(getattr(tweet, field))
    return tweet_dict

def scrape_tweets(account, since, until, max_tweets=None):
    print("start scraping since {} until {}".format(since, until))
    tweets = []
    params = {'from': account['username']}
    for k,v in {'since_time':since, 'until_time':until}.items():
        params[k] = int(datetime.datetime.timestamp(v))
    match = [':'.join([key,str(val)]) for key,val in params.items()]
    match = ' '.join(match)
    print(account['displayname'])
    print(match)
    # for i,tweet in enumerate(sntwitter.TwitterSearchScraper(match).get_items()):
    #     if max_tweets is not None and i > max_tweets:
    #         break
    #     tweets.append(build_tweet(tweet, account))
    # if len(tweets) > 0:
    #     db.tweets.insert_many(tweets)
    # else:
    #     print("no tweets") 



def scraping_parties(df):
    db.party_tweets.drop()
    parties_dict = df.to_dict('records')
    # print(parties_dict)
    session = db.scrap_sessions.find_one()
    since = session['since']
    until = session['until']
    for party_dict in parties_dict:
        account = {
            'group': party_dict['group'],
            'username': party_dict['twitter'],
        }
        tweets = []
        params = {'from': party_dict['twitter']}
        for k,v in {'since_time':since, 'until_time':until}.items():
            params[k] = int(datetime.datetime.timestamp(v))
        match = [':'.join([key,str(val)]) for key,val in params.items()]
        match = ' '.join(match)
        print(match)
        for i,tweet in enumerate(sntwitter.TwitterSearchScraper(match).get_items()):        
            tweets.append(build_tweet(tweet, account, party=True))
        if len(tweets) > 0:
            db.party_tweets.insert_many(tweets)
        else:
            print("no tweets")


def start_scraping(accounts_df, reset_db=False, scrap_accounts=True, continue_with=None):
    # reset db
    # if reset_db:
    #     db.accounts.drop()
    #     db.tweets.drop()
    #     db.scrap_sessions.drop()
    # log scrapping
    if continue_with:
        session = db.scrap_sessions.find_one()
    else:
        session = {}
        session['until'] = datetime.datetime.now()
        session['since'] = session['until'] - datetime.timedelta(days=365*2)
        db.scrap_sessions.insert_one(session)
    # scrap accounts
    if scrap_accounts:
        accounts_dict = accounts_df.to_dict('records')
        accounts = []
        for account_dict in accounts_dict:
            account = get_account(account_dict)
            if account:
                accounts.append(account)
            else:
                print("scraping error on this account: https://twitter.com/{}".format(account_dict['twitter']))
        db.accounts.insert_many(accounts)
    # scrap tweets
    accounts = db.accounts.find()
    for account in accounts:
        if continue_with and account['username'] == continue_with:
            continue_with = None
        if not continue_with:
            scrape_tweets(account, since=session['since'], until=session['until'])

# %%
scraping_parties(df_party)
# Out:
# [{'group': 'AGIR-E', 'twitter': 'AgirEnsemble_AN'}, {'group': 'DEM', 'twitter': 'MoDem'}, {'group': 'DLF', 'twitter': 'DLF_Officiel'}, {'group': 'EDS', 'twitter': 'edsassnat'}, {'group': 'FI', 'twitter': 'FranceInsoumise'}, {'group': 'GDR', 'twitter': 'deputesPCF'}, {'group': 'GE', 'twitter': 'GEcologie'}, {'group': 'LAREM', 'twitter': 'enmarchefr'}, {'group': 'LDS', 'twitter': 'Liguedusud'}, {'group': 'LND', 'twitter': 'NDemocrates_'}, {'group': 'LR', 'twitter': 'lesRepublicains'}, {'group': 'LT', 'twitter': 'GroupeLibTerrAN'}, {'group': 'RN', 'twitter': 'RNational_off'}, {'group': 'SOC', 'twitter': 'socialistesAN'}, {'group': 'UDI_I', 'twitter': 'UDI_off'}]
# from:AgirEnsemble_AN since_time:1566620921 until_time:1629692921
# from:MoDem since_time:1566620921 until_time:1629692921
# from:DLF_Officiel since_time:1566620921 until_time:1629692921
# from:edsassnat since_time:1566620921 until_time:1629692921
# from:FranceInsoumise since_time:1566620921 until_time:1629692921
# from:deputesPCF since_time:1566620921 until_time:1629692921
# from:GEcologie since_time:1566620921 until_time:1629692921
# from:enmarchefr since_time:1566620921 until_time:1629692921
# from:Liguedusud since_time:1566620921 until_time:1629692921
# from:NDemocrates_ since_time:1566620921 until_time:1629692921
# from:lesRepublicains since_time:1566620921 until_time:1629692921
# from:GroupeLibTerrAN since_time:1566620921 until_time:1629692921
# from:RNational_off since_time:1566620921 until_time:1629692921
# from:socialistesAN since_time:1566620921 until_time:1629692921
# from:UDI_off since_time:1566620921 until_time:1629692921

# %%
# import logging
# logger = logging.getLogger()
# logger.disabled = True
start_scraping(df1, scrap_accounts=False)
print("Scraping done!")
# Out:
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Alain Tourret
# no tweets
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Monique Iborra
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# François de Rugy
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Jacqueline Maquet
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Gwendal ROUILLARD
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Thierry SOLERE
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Jacques Krabal
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Christophe Castaner
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Éric Alauzet
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Richard Ferrand
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Françoise Dumas
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Florent Boudié
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Patrick Vignal
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Yves DANIEL
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Sophie Errante
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# STEPHANE TRAVERT #ProtegezVous
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Hervé Pellois
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Yves Blein
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# eric bothorel ⌨️
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Frédéric Barbier
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Bruno Questel 🇫🇷
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Stella DUPONT
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Anne-Christine Lang
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Jean-Jacques Bridey #Vacciné
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Stéphane Mazars
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Stéphane Claireaux
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Mounir Mahjoubi
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# 🇨🇵🇪🇺 Sylvain Maillard
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Olga Givernet
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Stéphane Trompille
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Marc Delatte
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Pascale Boyer
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Laurence Vanceunebrock
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Aude Bono-Vandorme
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Alexandra Ardisson
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Danièle Hérin
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Alain Perea
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Mireille Robert
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Gregory Besson Moreau
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Loïc Dombreval 🐾
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Cédric ROUSSEL
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Claire Pitollat
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Anne-Laurence Petel
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Cathy RACON BOUZON
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Saïd Ahamada
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Jean-Marc Zulesi
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Anne Blanc
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Fabrice Le Vigoureux
# no tweets
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Bertrand Bouyx
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Thomas MESNIER
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Sandra Marsaud
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Raphaël Gérard
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# François Cormier-Bouligeon
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Monica Michel-Brassart
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Didier Martin 🎗
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Jacqueline Dubois
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Fannette Charvier
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Fadila Khattabi
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Didier PARIS
# no tweets
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Hervé Berville
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Yannick Kerlogot
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Jean Baptiste Moreau
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Philippe Chassaing
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Michel Delpon
# no tweets
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Mireille Clapot
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Alice Thourot
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Célia de Lavergne
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Séverine Gipson #Vaccinée
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Fabien Gouttefarde
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Graziella Melchior
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Marie Tamarelle Verhaeghe
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Claire  O'PETIT
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Guillaume Kasbarian
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Annaïg Le Meur
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# LE GAC Didier
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Sandrine Le Feur
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Denis Sommer
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Anthony Cellier
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Sandrine Mörch
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Jean-René Cazeneuve
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Pierre Cabaré
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Corinne Vignon
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Mickael Nogal
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Jean-François Portarrieu
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# E. Toutut-Picard
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Liliana TANGUY
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Catherine Fabre
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Eric POULLIAT
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Bérangère Couillard
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Sophie Panonacle
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Véronique HAMMERER
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Christelle Dubos
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Patricia MIRALLÈS #Vaccinée💉
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Coralie Dubost
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Jean-François Eliaou
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Dominique David
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Laurence Maillart M
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Gael Le Bohec
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Camille Galliard-Minier
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# J-C Colas-Roy
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Emilie CHALAS
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Christine Cloarec-Le Nabour
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Florian Bachelier
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# François Jolivet
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Philippe Chalumeau
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Labaronne Daniel
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Fabienne COLBOC
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Nicolas Démoulin
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Mustapha Laabid 🇫🇷
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Monique Limon
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Abadie Caroline
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Marjolaine Meynier
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Danielle Brulebois
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Lionel Causse
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Jean-Michel MIS 🇫🇷
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Valéria Faure-Muntian
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Julien Borowczyk
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Catherine Kamowski
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Michel Lauzzana
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Alexandre Freschi
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Audrey Dufeu
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Yannick Haury
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Stéphanie Rist
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Caroline Janvier
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Valérie Oppelt
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Anne-France BRUNET
# no tweets
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Aude Amadou
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Laetitia Saint-Paul
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Denis Masséglia
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Nicole Dubré Chirat
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Bertrand SORRE
# no tweets
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Sonia Krimi
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# GIRARDIN Eric
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Sylvain Templier
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Olivier Damaisin
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Christophe Arend
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Hélène Zannier
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Nicole Le Peih
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Jean-Michel JACQUES
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Belkhir Belhaddad
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Ludovic MENDES
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Richard Lioger
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Nicole Trisse
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Xavier Paluszkiewicz
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Christophe Di Pompeo
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Brigitte Liso
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Charlotte Parmentier Lecocq
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Osson Catherine
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Florence Morlighem
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Anne-Laure Cattelot
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Isabelle Rauch
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Pascal BOIS
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Carole BureauBonnard
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Thierry Michels
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Bruno Studer
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# JB Sempastous
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Romain Grau
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Laurence GAYTE
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Sebastien Cazenove
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Valérie THOMAS
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Frédéric Descrozaille
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# 𝗝𝗲𝗮𝗻 𝗙𝗿𝗮𝗻𝗰𝗼𝗶𝘀 𝗠𝗯𝗮𝘆𝗲
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Laurent Saint-Martin
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Cécile RILHAC
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Fiona Lazaar
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Dominique da Silva
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Olivier SERVA
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Amelia Lakrafi
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Anne GENETET
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Lénaïck ADAM
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Roland Lescure
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Alexandre Holroyd
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Pieyre-Alexandre Anglade
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Samantha Cazebonne
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Sylvie Charrière
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Guillaume Vuilletet
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Patrice Anato
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Guillaume Gouffier
# start scraping since 2019-08-24 06:28:41.731000 until 2021-08-23 06:28:41.731000
# Anne Brugnera
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19188/3900318205.py in <module>
#       2 # logger = logging.getLogger()
#       3 # logger.disabled = True
# ----> 4 start_scraping(df1, scrap_accounts=False, continue_with="AlainTourret")
#       5 print("Scraping done!")
#
# ~\AppData\Local\Temp/ipykernel_19188/3686485323.py in start_scraping(accounts_df, reset_db, scrap_accounts, continue_with)
#      90             continue_with = None
#      91         if not continue_with:
# ---> 92             scrape_tweets(account, since=session['since'], until=session['until'])
#
# ~\AppData\Local\Temp/ipykernel_19188/3686485323.py in scrape_tweets(account, since, until, max_tweets)
#      54         tweets.append(build_tweet(tweet, account))
#      55     if len(tweets) > 0:
# ---> 56         db.tweets.insert_many(tweets)
#      57     else:
#      58         print("no tweets")
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymongo\collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     768         blk = _Bulk(self, ordered, bypass_document_validation)
#     769         blk.ops = [doc for doc in gen()]
# --> 770         blk.execute(write_concern, session=session)
#     771         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     772
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymongo\bulk.py in execute(self, write_concern, session)
#     527                 self.execute_no_results(sock_info, generator)
#     528         else:
# --> 529             return self.execute_command(generator, write_concern, session)
#     530
#     531
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymongo\bulk.py in execute_command(self, generator, write_concern, session)
#     358         client = self.collection.database.client
#     359         with client._tmp_session(session) as s:
# --> 360             client._retry_with_session(
#     361                 self.is_retryable, retryable_bulk, s, self)
#     362
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1436         retryable = (retryable and self.retry_writes
#    1437                      and session and not session.in_transaction)
# -> 1438         return self._retry_internal(retryable, func, session, bulk)
#    1439
#    1440     def _retry_internal(self, retryable, func, session, bulk):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymongo\mongo_client.py in _retry_internal(self, retryable, func, session, bulk)
#    1468                             raise last_error
#    1469                         retryable = False
# -> 1470                     return func(session, sock_info, retryable)
#    1471             except ServerSelectionTimeoutError:
#    1472                 if is_retrying():
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymongo\bulk.py in retryable_bulk(session, sock_info, retryable)
#     352
#     353         def retryable_bulk(session, sock_info, retryable):
# --> 354             self._execute_command(
#     355                 generator, write_concern, session, sock_info, op_id,
#     356                 retryable, full_result)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymongo\bulk.py in _execute_command(self, generator, write_concern, session, sock_info, op_id, retryable, full_result)
#     308                 ops = islice(run.ops, run.idx_offset, None)
#     309                 # Run as many ops as possible in one command.
# --> 310                 result, to_send = bwc.execute(ops, client)
#     311
#     312                 # Retryable writeConcernErrors halt the execution of this run.
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymongo\message.py in execute(self, docs, client)
#     948     def execute(self, docs, client):
#     949         request_id, msg, to_send = self._batch_command(docs)
# --> 950         result = self.write_command(request_id, msg, to_send)
#     951         client._process_response(result, self.session)
#     952         return result, to_send
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymongo\message.py in write_command(self, request_id, msg, docs)
#    1040             start = datetime.datetime.now()
#    1041         try:
# -> 1042             reply = self.sock_info.write_command(request_id, msg)
#    1043             if self.publish:
#    1044                 duration = (datetime.datetime.now() - start) + duration
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymongo\pool.py in write_command(self, request_id, msg)
#     796
#     797         # Raises NotPrimaryError or OperationFailure.
# --> 798         helpers._check_command_response(result, self.max_wire_version)
#     799         return result
#     800
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pymongo\helpers.py in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     165         raise CursorNotFound(errmsg, code, response, max_wire_version)
#     166
# --> 167     raise OperationFailure(errmsg, code, response, max_wire_version)
#     168
#     169
#
# OperationFailure: you are over your space quota, using 517 MB of 512 MB, full error: {'ok': 0, 'errmsg': 'you are over your space quota, using 517 MB of 512 MB', 'code': 8000, 'codeName': 'AtlasError'}

# %%
accounts = db.accounts.find()
for account in accounts:
    print(account['username'])
# Out:
# antoineherth
# agnesfirmin
# christophe_p
# becht_olivier
# MainaSage
# VincentLedoux59
# ALouisDeputee13
# LoicKervran18
# lauredlr
# JCLarsonneur
# chapelierannie
# ChristopheEuzet
# PhilippeHuppe
# ainakuric
# lise_magnier
# dhoubron1759
# BenoitPotterie
# mjidelguerrab
# pybournazel
# tgassilloud
# michelfanget
# VigierPhilippe
# fpupponi
# laqhila
# NadiaEssayan
# chrisjerretie
# BJoncour
# PBertaGard
# JeanLucLAGLEIZE
# erwanbalanant
# SophieMette1
# SabineThillaye
# elodiejala
# fabien_laine
# GeismarLuc
# _richardramos
# phbolo
# GarciaLaxou
# Bannier_G
# BHammouche5708
# EnMarche_56
# MDeprezAudebert
# LVichnievsky
# josypoueyto
# jp_mattei
# SylvainWaserman
# bru_vincent
# Justine_BENIN
# MaxMathiasin
# fpetitAN
# MaudPetit_AN94
# BBrocard
# f_personne
# PatrickMignola
# PhilippeMichelK
# iflorennes92
# maudgatel
# MicheleCrouzet
# jnbarrot
# MdeVaucouleurs
# BrunoMillienne
# platombe
# PLoiseau85
# TurquoisNicolas
# bruno_fuchs
# CIsaacSibille
# dupontaignan
# emenard34
# M_Orphelin
# PaulaForteza
# AlbaneGaillot
# VillaniCedric
# MartineWonner
# JLMelenchon
# Clem_Autain
# BenedictTaurine
# Michel_Larive
# PrudhommeLoic
# MRessiguier
# CarolineFiat54
# AQuatennens
# Ugobernalicis
# LachaudB
# MathildePanot
# DeputeRatenon
# ericcoquerel
# alexiscorbiere
# SabineRubinFI93
# Deputee_Obono
# Francois_Ruffin
# AndreChassaigne
# JP_Dufregne
# pdharreville
# alain_bruneel
# Moetai1
# stephane1peu
# ElsaFaucillon
# sebastienjumel
# delphinebatho
# hub_laferriere
# JeanPierrePont
# AlainTourret
# MoniqueIborra
# FdeRugy
# JMaquetDeputee
# G_ROUILLARD
# solere92
# JKrabal
# CCastaner
# ericalauzet
# RichardFerrand
# fdumasdeputee
# florent_boudie
# PatrickVignal
# ydaniel_depute
# SophieErrante
# StTRAVERT
# HervePellois
# yves_blein
# ebothorel
# Fred_Barbier
# BQuestel
# stelladupont
# AChristine_Lang
# jjbridey94260
# S_Mazars
# sclaireaux
# mounir
# SylvainMaillard
# OlgaGivernet
# S_Trompille
# MarcDelatte
# PascaleBoyerEM
# LaurenceVanceu
# AudeBono
# A_Ardisson
# Daniele_herin
# PereaAlain
# MRobert_11
# GBessonMoreau
# LoicDombreval
# CedricRoussel06
# ClairePitollat
# al_petel
# RaconCathy
# saidahamada
# jmzulesi
# AnneBlanc_12
# LeVigoureuxF
# BertrandBouyx
# MESNIERThomas
# MARSAUDSandra
# RaphaelGerard17
# FCBDeputeduCher
# MonicaMichel_Of
# dmartindijon
# Jacqlinedubois
# F_Charvier
# KhattabiF
# DidierPARIS
# HerveBerville
# Kerlogot22
# moreaujb23
# ChassaingPh
# MichelDelpon
# CLAPOTMireille
# AliceThourot
# CdLavergne
# severine_gipson
# FGouttefarde
# GrazieMelchior
# marietamarelle
# claireopetit
# guillaumekasba
# AnnaigLeMeur_AN
# didierlegac
# SandrineLeFeur
# DenisSommer
# anthonycellier
# SandrineMorch
# jrcazeneuve
# DeputeCabareP
# corinnevignon
# MickaelNogal
# jfportarrieu
# etoututpicard
# LilianeTanguyAN
# cfabreAN
# EPoulliat
# BCouillard33
# SoPanonacle
# V_Hammerer
# duboschristelle
# MIRALLESMP
# CoDubost
# JFEliaou
# DominiqueDavid_
# LMaillart
# GaelLeBohec
# GalliardM
# JCColasRoy
# EmilieCChalas
# ChrisCloarec
# F_BACHELIER
# FJolivet36
# Chalumeau_P
# LabaronneDaniel
# fabiennecolboc
# DemoulinEM
# mustapha_laabid
# 3807Limon
# AbadieCaroline
# M_MeynierM
# dbrulebois
# DeputeCausse
# JeanMichelMIS
# V_Faure_Muntian
# JulienBorowczyk
# CKamowski3805
# lauzzanamichel
# AVFreschi
# audreydufeu
# YHaury44
# stephanie_rist
# CarolineJanvier
# valerie_oppelt
# nneFranceBrunet
# AudeAmadou
# l_saintpaul
# denis_Masseglia
# NicoleDubre17
# BertrandSorre
# Sonia_Krimi
# GirardinEric
# sylv1templier
# olivierdam1
# christophearend
# HeleneZannier
# NicoleLePeih
# J_M_Jacques
# b_belhaddad
# ludovicMDS
# RichardLioger
# NicoleTrisse
# XavierPalu2017
# DipompeoChrist
# brigitte_liso
# lecocqcharlotte
# OssonCatherine
# FMorlighem
# ALCattelot
# IsabelleRauch
# PascalBoisLaREM
# CaroleBBonnard
# ThierryMichels
# BrunoStuder67
# Sempastoushp
# RomainGrau
# LaurenceGayte
# SebCazenove
# Vthomas_63
# fdescrozaille
# JFMBAYE
# LauStmartin
# Cecile_Rilhac
# FionaLazaar
# DDaSilva95
# olivier_serva
# Amelia_LKF
# AGenetet
# LenaickADAM
# RolandLescure
# alexIholroyd
# PA_Anglade
# scazebonne
# SylvieCharriere
# g_vuilletet
# Patrice_Anato
# G_GouffierCha
# AnneBrugnera
# BrunoBonnellOff
# Gauvain_Raphael
# DamienPichereau
# Typhanie_Degois
# V_Riotton
# F_Lardet
# marion_lenne
# GillesLeGendre
# StanGuerini
# SKerbarh
# XavierBatut
# MRoquesetienne
# VerdierJouclas
# Pierr_Person
# JeanTerlier
# lauriannerossi
# PacomeRupin
# LaetitiaAvia
# RKokouendoJ
# CMUSCHOTTI
# StephanieAtger
# BuonTAN
# MichelePeyron
# DoStephanie_77
# SereineEnMarche
# celinecalvez
# mariesilin
# dbaichere
# VGB83
# eguerelLREM
# famatras
# huguesrenson
# BeatricePiron
# MarieLebec78
# AdrienMorenas
# mguevenoux
# PA_Raphan
# YaelBRAUNPIVET
# npouzyreff78
# jmarilossian
# StephaneBuchou
# LeguilleBalloy
# Romeiro1L
# damienadam76
# auroreberge
# fgranjus
# HenrietPierre
# fballetblu
# DeputeeBPetelle
# Ch_Hennion
# Vidal7602
# sirasylla76
# JeanMarieFIEVET
# sach_he
# BeaudouinSo
# JMaireofficiel
# flprovendier
# C_Delpirou
# JLeclabart
# PierreVenteau
# MarieAngeMagne
# RixainMP
# trudigoz
# Anissa_Khedher
# B_BessotBallot
# lejeune_ch
# VincentThiebaut
# Jean_LucFUGIT
# BenjaminDirx
# RRebeyrotte
# fchouat
# FranceLorho
# DBagarry
# EmilieCariou
# Aurelientache
# GuillaumeChiche
# delaverpilliere
# BDeflesselles
# N_Forissier
# ChJacob77
# marclefur
# B_Perrut
# didierquentin
# JL_Reitzer
# phgosselin
# VRolland73
# SebastienHuyghe
# jmsermier2014
# Poletti_B
# doorjean
# JCGrelier
# JJ_Gaultier
# genevievelevy83
# DinoCinieri
# DiardEric
# Cdganay
# GLarrive
# MTabarot
# guyteissier
# ericwoerth
# bretonxavier
# ECiotti
# bernardreynes
# VincentDescoeur
# JCBOUCHET
# duboismarianne
# ConstanceLeGrip
# emmanuel_maquet
# BouleyBernard
# damienabad
# AnnieGenevard
# oliviermarleix
# J_PVigier
# VeroLouwagie
# patrickhetzel
# DubyMuller
# JulienAubert84
# thibault_bazin
# jjferrarafb
# isavalentin43
# JulienDive
# marinebrenier
# EricPAUGET1
# FabriceBrun
# CORDIERPierre08
# VBazinMalgras
# JuRavier
# nathporte
# eanthoine26
# G_Peltier
# AurelienPradie
# beauvais2017
# FabienDiFilippo
# MaximeMinot
# jeromenury
# phdumont
# NathalieBassire
# David_Lorion
# alainramadier
# RSCactu
# BonnivardE
# ViryStephane
# brigitte_kuster
# SBouchetB
# robinreda
# IanBoucard
# SBoelle
# MichelVialay
# GillesCarrez
# antoine7595
# JCattin2017
# PhilipBenassaya
# AnneLaureBlin
# YvesHemedinger
# GerardCherpion
# FCornutGentille
# jeanlassalle
# BertrandPancher
# SylviaPinel
# jmclement86
# fm_lambert
# OlivierFalorni
# Paul_Molac
# Castellani_
# JF_Acquaviva
# pacolombani
# Sebastien_Nadot
# BenoitSimian
# JDetemmerman
# DumasFrederique
# C_deCourson
# NMeizonnet
# sebchenu
# MLP_officiel
# CatherinePUJOL1
# BrunoBilde
# AlainDavid_AN
# LDumontDeputee
# DavidDhabib
# jeromelambert16
# Juanico
# guillaumegarot
# ChristianHutin
# MKaramanli72
# hsaulignac
# claudia_rouaux
# BattistelMarie
# GiseleBiemouret
# jlbricout
# PotierDominique
# cpiresbeaune
# ceciluntermaier
# SylvieTolmont
# faureolivier
# Valerie_Rabault
# JAviragnet
# HeleneVainqueur
# PNaillet
# BorisVallaud
# LeseulG
# isasantiago_94
# MORELPIERRE
# yfavennec
# MichelZumkeller
# jclagarde
# warsmann
# ThierryBenoit35
# pascalbrindeau
# PhilippeGomesCE
# Meyer_Habib
# six_valerie
# ThillAgnes
# beadescamps
